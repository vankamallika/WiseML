# %% [markdown]
# <a href="https://colab.research.google.com/github/TetaliVarshitha/WiseML/blob/main/Apyori.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import matplotlib.pyplot as plt  
import pandas as pd  
from apyori import apriori

# %%
data = pd.read_csv('/content/drive/MyDrive/Machine Learning/Grocery Products Purchase.csv')

# %%
data.head()
# Out:
#           Product 1            Product 2  ... Product 31 Product 32
# 0      citrus fruit  semi-finished bread  ...        NaN        NaN
# 1    tropical fruit               yogurt  ...        NaN        NaN
# 2        whole milk                  NaN  ...        NaN        NaN
# 3         pip fruit               yogurt  ...        NaN        NaN
# 4  other vegetables           whole milk  ...        NaN        NaN
#
# [5 rows x 32 columns]

# %%
# !pip install apyori
# Out:
# ...
#   Created wheel for apyori: filename=apyori-1.1.2-cp37-none-any.whl size=5975 sha256=f9231a9ba0e298dc044046a32a72270e55a2954a7f093b02578370674442ba2c
#   Stored in directory: /root/.cache/pip/wheels/5d/92/bb/474bbadbc8c0062b9eb168f69982a0443263f8ab1711a8cad0
# Successfully built apyori
# ...

# %%
records = []  
for i in range(0, 7501):  
    records.append([str(data.values[i,j]) for j in range(0, 20)])
records
# Out:
# [['citrus fruit',
#   'semi-finished bread',
#   'margarine',
#   'ready soups',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['tropical fruit',
#   'yogurt',
#   'coffee',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['whole milk',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['pip fruit',
#   'yogurt',
#   'cream cheese',
#   'meat spreads',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['other vegetables',
# ...

# %%
association_rules = apriori(records, min_support=0.0045, min_confidence=0.2, min_lift=3, min_length=2)  

association_results = list(association_rules)

print(association_results)
# Out:
# [RelationRecord(items=frozenset({'whipped/sour cream', 'baking powder'}), support=0.005065991201173177, ordered_statistics=[OrderedStatistic(items_base=frozenset({'baking powder'}), items_add=frozenset({'whipped/sour cream'}), confidence=0.2835820895522388, lift=3.8816592221374875)]), RelationRecord(items=frozenset({'root vegetables', 'beef'}), support=0.01759765364618051, ordered_statistics=[OrderedStatistic(items_base=frozenset({'beef'}), items_add=frozenset({'root vegetables'}), confidence=0.3464566929133858, lift=3.1348270850944595)]), RelationRecord(items=frozenset({'whipped/sour cream', 'berries'}), support=0.007732302359685375, ordered_statistics=[OrderedStatistic(items_base=frozenset({'berries'}), items_add=frozenset({'whipped/sour cream'}), confidence=0.25, lift=3.4219890510948905)]), RelationRecord(items=frozenset({'bottled beer', 'liquor'}), support=0.004532728969470737, ordered_statistics=[OrderedStatistic(items_base=frozenset({'liquor'}), items_add=frozenset({'bottled be
# ...

# %%
sorted(association_results, key=lambda x: x[2][0][3], reverse=True)
# Out:
# [RelationRecord(items=frozenset({'flour', 'sugar'}), support=0.005065991201173177, ordered_statistics=[OrderedStatistic(items_base=frozenset({'flour'}), items_add=frozenset({'sugar'}), confidence=0.28787878787878785, lift=8.63751515151515)]),
#  RelationRecord(items=frozenset({'flour', 'nan', 'sugar'}), support=0.004932675643247567, ordered_statistics=[OrderedStatistic(items_base=frozenset({'flour'}), items_add=frozenset({'nan', 'sugar'}), confidence=0.28030303030303033, lift=8.617020615996028), OrderedStatistic(items_base=frozenset({'flour', 'nan'}), items_add=frozenset({'sugar'}), confidence=0.29365079365079366, lift=8.810698412698413)]),
# ...

# %%
for item in association_results:
    print([x for x in item[0]])
# Out:
# ['whipped/sour cream', 'baking powder']
# ['root vegetables', 'beef']
# ['whipped/sour cream', 'berries']
# ['bottled beer', 'liquor']
# ['red/blush wine', 'bottled beer']
# ['flour', 'sugar']
# ['grapes', 'tropical fruit']
# ['ham', 'white bread']
# ['root vegetables', 'herbs']
# ['white bread', 'processed cheese']
# ['sliced cheese', 'sausage']
# ['whipped/sour cream', 'baking powder', 'nan']
# ['baking powder', 'whole milk', 'other vegetables']
# ['root vegetables', 'nan', 'beef']
# ['root vegetables', 'other vegetables', 'beef']
# ['rolls/buns', 'root vegetables', 'beef']
# ['whole milk', 'root vegetables', 'beef']
# ['yogurt', 'root vegetables', 'beef']
# ['whipped/sour cream', 'berries', 'nan']
# ['nan', 'bottled beer', 'liquor']
# ['red/blush wine', 'bottled beer', 'nan']
# ['domestic eggs', 'whole milk', 'butter']
# ['whipped/sour cream', 'butter', 'other vegetables']
# ['whipped/sour cream', 'whole milk', 'butter']
# ['whipped/sour cream', 'chicken', 'other vegetables']
# ...

# %%
for item in sorted(association_results, key=lambda x: x[2][0][3], reverse=True)[:5]:

    # first index of the inner list
    # Contains base item and add item
    pair = item[0]  # frozenset:{light cream, chicken}
    items = [x for x in pair] #['light cream', 'chicken']
    print("Rule: " + items[0] + " -> " + items[1])

    #second index of the inner list
    print("Support: " + str(item[1]))

    #third index of the list located at 0th
    #of the third index of the inner list

    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("=====================================")
# Out:
# Rule: flour -> sugar
# Support: 0.005065991201173177
# Confidence: 0.28787878787878785
# Lift: 8.63751515151515
# ...
# Rule: flour -> nan
# Support: 0.004932675643247567
# Confidence: 0.28030303030303033
# Lift: 8.617020615996028
# ...
# Rule: citrus fruit -> tropical fruit
# Support: 0.004666044527396347
# Confidence: 0.26717557251908397
# Lift: 7.534150261149056
# ...
# Rule: white bread -> nan
# Support: 0.004666044527396347
# Confidence: 0.29411764705882354
# Lift: 7.00373482726424
# ...
# Rule: white bread -> processed cheese
# Support: 0.004799360085321957
# Confidence: 0.3025210084033613
# Lift: 7.003734827264238
# ...
